# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from numpy.random import randn
from scipy import array, newaxis
from numpy import genfromtxt

# %%
# %matplotlib inline

def show_data(filepath, xlabel, ylabel, zlabel):
    DATA = genfromtxt(filepath, delimiter=',', skip_header=1)
    Xs = DATA[:,0] # gens_count or iters_counts
    Ys = DATA[:,1] # path_length
    Zs = DATA[:,2] # time_elapsed

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_trisurf(Xs, Ys, Zs, cmap=cm.jet, linewidth=0)
    fig.colorbar(surf, shrink=0.9, pad = 0.1)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_zlabel(zlabel)

    ax.xaxis.set_major_locator(MaxNLocator(5))
    ax.yaxis.set_major_locator(MaxNLocator(6))
    ax.zaxis.set_major_locator(MaxNLocator(5))

    ax.view_init(30, 130)

    fig.tight_layout()
    # rotate the axes and update
    plt.savefig(f'{filepath}.png')

    plt.show()

def show_data2d(filepath, xlabel, ylabel, zlabel):
    DATA = genfromtxt(filepath, delimiter=',', skip_header=1)
    Xs = DATA[:,0] # gens_count or iters_counts
    Ys = DATA[:,1] # path_length
    Zs = DATA[:,2] # time_elapsed

    plt.xlabel(zlabel)
    plt.ylabel(ylabel)

    plt.plot(Zs, Ys, 'bo')

    z = np.polyfit(Zs, Ys, 1)
    p = np.poly1d(z)
    plt.plot(Zs ,p(Zs),"r--")

    plt.savefig(f'{filepath}_2d.png')
    plt.show()

# %%
show_data('sphere_ga_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('sphere_ga_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('sphere_ga_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('sphere_ma_test_10.csv', 'iters_count', 'path_length', 'time_elapsed')

# %%
show_data('sphere_ma_test_100.csv', 'iters_count', 'path_length', 'time_elapsed')

# %%
show_data('sphere_ga_test_500.csv', 'iters_count', 'path_length', 'time_elapsed')

# %%
show_data2d('sphere_ga_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('sphere_ga_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('sphere_ga_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('sphere_ma_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('sphere_ma_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('sphere_ma_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('discrete_ga_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('discrete_ga_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('discrete_ga_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('discrete_ga_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('discrete_ga_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('discrete_ga_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('discrete_ma_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('discrete_ma_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data('discrete_ma_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('discrete_ma_test_10.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('discrete_ma_test_100.csv', 'gens_count', 'path_length', 'time_elapsed')

# %%
show_data2d('discrete_ma_test_500.csv', 'gens_count', 'path_length', 'time_elapsed')
